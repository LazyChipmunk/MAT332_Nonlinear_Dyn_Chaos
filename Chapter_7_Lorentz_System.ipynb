# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 2, color='r',fill=False,linewidth=3)
circle2 = plt.Circle((0, 0), 1, color='g',fill=False,linewidth=3)
# 1D arrays
x = np.arange(-3,3,0.02)
y = np.arange(-3,3,0.02)

# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y + X*(1- X*X - Y*Y )
Ey = -X + Y*(1- X*X - Y*Y )

# Depict illustration

fig=plt.figure(figsize=(10, 10))
gs = gridspec.GridSpec(nrows=1, ncols=2, width_ratios = [1,1])
ax1 = fig.add_subplot(gs[0, 0])


ax.cla() # clear things for fresh plot

# change default range so that new circles will work
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=2, linewidth=None)
ax1.add_patch(circle2)
ax1.plot(0,0,'-or')
ax1.set_aspect('equal')
ax1.set_title('Not a Trapping region',fontsize=20)
# change default range so that new circles will work
ax2 = fig.add_subplot(gs[0, 1])
ax2.set_xlim((-3, 3))
ax2.set_ylim((-3, 3))
ax2.streamplot(X,Y,Ex,Ey,density=2, linewidth=None)
ax2.add_patch(circle1)
ax2.plot(0,0,'-or')
ax2.set_title('A Trapping region',fontsize=20)
ax2.set_aspect('equal')

# Show plot with gird

#plt.grid()
plt.show()

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 2, color='r',fill=False,linewidth=3)
circle2 = plt.Circle((0, 0), 1, color='g',fill=False,linewidth=3)
# 1D arrays

y = np.arange(-0.5,0.5,0.05)

t = np.arange(-3,3,0.02)


# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y + X*(1- X*X - Y*Y )
Ey = -X + Y*(1- X*X - Y*Y )

# Depict illustration

fig=plt.figure(figsize=(10, 10))
ax1=fig.add_subplot()


ax.cla() # clear things for fresh plot

# change default range so that new circles will work
ax1.set_xlim((-1, 3))
ax1.set_ylim((-2, 2)) 
for k in y:
    x = k*np.exp(t)
    ax1.plot(t,x,"b-")
ax1.set_aspect('equal')
# change default range so that new circles will work

ax1.spines['left'].set_position('zero')
ax1.spines['right'].set_color('none')
ax1.spines['bottom'].set_position('zero')
ax1.spines['top'].set_color('none')

x=0*y
ax1.plot(x,y,"r-", linewidth=4)
y1=y*np.exp(1)
x1=x+1 
ax1.plot(x1,y1,"m-", linewidth=4)
ax1.text(3, 0, 't', fontsize=16)
ax1.text(0.1, 1.9, 'x(t)', fontsize=16)
ax1.arrow(0.1, 1, 0.5, 0,shape='full',head_width=0.1)
ax1.arrow(0.1, -1.1, 0.5, 0,shape='full',head_width=0.1)
# Show plot with gird

#plt.grid()
plt.show()

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 2, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), 1, color='tab:orange',fill=True,linewidth=3)
circle3 = plt.Circle((0, 0), 0.3, color='y',fill=True,linewidth=3)
circle11 = plt.Circle((0, 0), 2, color='r',fill=True,linewidth=3)
circle22 = plt.Circle((0, 0), 1, color='tab:orange',fill=True,linewidth=3)
circle33 = plt.Circle((0, 0), 0.3, color='y',fill=True,linewidth=3)
# 1D arrays
x = np.arange(-4,4,0.02)
y = np.arange(-4,4,0.02)

# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y - X*np.sqrt(X*X + Y*Y )
Ey = -X - Y*np.sqrt( X*X + Y*Y )

# Depict illustration

fig=plt.figure(figsize=(20, 20))
gs = gridspec.GridSpec(nrows=2, ncols=3, height_ratios= [1,1], width_ratios = [1,1,1])



# change default range so that new circles will work

# change default range so that new circles will work
ax1 = fig.add_subplot(gs[0, 0])
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=2, linewidth=1.5)
ax1.add_patch(circle1)
ax1.set_aspect('equal')
ax1.axis("off")
ax1.set_title('Flow of Region at t=0',fontsize=20)
# Show plot with gird
ax1 = fig.add_subplot(gs[0, 1])
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=2, linewidth=1.5)
ax1.add_patch(circle2)
ax1.set_aspect('equal')
ax1.axis("off")
ax1.set_title('Flow of Region at t=1',fontsize=20)
ax1 = fig.add_subplot(gs[0, 2])
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=2, linewidth=1.5)
ax1.add_patch(circle3)
ax1.set_aspect('equal')
ax1.axis("off")
ax1.set_title('Flow of Region at t=2',fontsize=20)


ax2 = fig.add_subplot(gs[1, 0])
ax2.add_patch(circle11)
ax2.add_patch(circle22)
ax2.add_patch(circle33)
ax2.set_xlim((-3, 3))
ax2.set_ylim((-3, 3))
ax2.axis("off")
ax2.set_aspect('equal')

ax2 = fig.add_subplot(gs[1, 1])
ax2.arrow(-1, 0, 2, 0,shape='full',head_width=0.2)
ax2.text(-3,0.5, 'Intersect all the (infinitely many) discs', fontsize=20)
ax2.set_xlim((-3, 3))
ax2.set_ylim((-3, 3))
ax2.axis("off")
ax2.set_aspect('equal')

ax2 = fig.add_subplot(gs[1, 2])

ax2.set_xlim((-3, 3))
ax2.set_ylim((-3, 3))
ax2.plot(0,0, "b")
circle0 = plt.Circle((0, 0), 0.05, color='b',fill=True,linewidth=3)
ax2.text(-1,0.2, 'The Origin', fontsize=20)
ax2.add_patch(circle0)
ax2.axis("off")
ax2.set_aspect('equal')

plt.axis("off")


#plt.grid()
plt.show()

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1


circle7 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle8 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle9 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)

circle10 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3,zorder=10)
circle11 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle12 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)





# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=1, ncols=2, width_ratios = [1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p





r=1
ax5 = fig.add_subplot(gs[0, 1])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2]
U =[0.3,0.3,0,-0.3,0.3,0.2,0,-0.5,-0.4]
ax5.quiver(X, Y, U, V, color='k', units='xy', scale=1)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax5.set_xlim((-3, 3))
ax5.set_ylim((-3, 3))
ax5.add_patch(circle7)
ax5.add_patch(circle8)
ax5.add_patch(circle9)
p = np.linspace(-1,1,100)
q = 0*p-2
plt.plot(q, p, '-b',linewidth=2,zorder=0)
q = 0*p+2
plt.plot(q, p, '-b',linewidth=2,zorder=0)
ax5.arrow(0.5, 1, 1.3, 0, head_width=0.1, head_length=0.1, fc='b', ec='b')
ax5.arrow(-0.5, 1, -1.3, 0, head_width=0.1, head_length=0.1, fc='b', ec='b')
ax5.text(-0.1,0.9, 'U', color= 'b',fontsize=20)

p = np.linspace(-0.5,0.5,100)
q = 0*p-1.5
plt.plot(q, p, 'tab:orange',linewidth=2,zorder=0)
q = 0*p-0.5
plt.plot(q, p, 'tab:orange',linewidth=2,zorder=0)
ax5.arrow(-0.8, -0.4, 0.2, 0, head_width=0.1, head_length=0.1, fc='tab:orange', ec='tab:orange')
ax5.arrow(-1.2, -0.4, -0.2, 0, head_width=0.1, head_length=0.1, fc='tab:orange', ec='tab:orange')
ax5.text(-1.1,-0.4, 'V', color= 'tab:orange',fontsize=20)


ax5.axis('off')
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p
ax6 = fig.add_subplot(gs[0, 0])
x = np.linspace(-2,2,100)
y = r*x-x**3 
ax6.plot(x, y, '-k',linewidth=1,zorder=0)

ax6.set_xlim((-3, 3))
ax6.set_ylim((-3, 3))
ax6.add_patch(circle10)
ax6.add_patch(circle11)
ax6.add_patch(circle12)
ax6.text(2,0.1, 'x' ,fontsize=20)
ax6.text(0.1,2, 'y' ,fontsize=20)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)



ax6.set_aspect('equal')
ax6.axis('off')


# Show plot with gird

plt.show()

# %%
    
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 2, color='g',fill=False,linewidth=3,zorder=10)
circle2 = plt.Circle((0, 0), 0.05, color='g',fill=True,linewidth=3,zorder=10)
circle3 = plt.Circle((0, 0), 1, color='r',fill=False,linewidth=3,zorder=10)
circle4 = plt.Circle((0, 0), 2.5, color='tab:orange',fill=True,linewidth=3)
circle11 = plt.Circle((0, 0), 2, color='g',fill=False,linewidth=3,zorder=10)
circle22 = plt.Circle((0, 0), 0.05, color='g',fill=True,linewidth=3,zorder=10)
circle33 = plt.Circle((0, 0), 1, color='r',fill=False,linewidth=3)

wedge = mpatches.Wedge((0, 0), 2.5, 0, 360, width=1,color='tab:orange', zorder=0)
# 1D arrays
x = np.arange(-4,4,0.02)
y = np.arange(-4,4,0.02)

# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y + X*(1-X*X - Y*Y)*(X*X + Y*Y-4) 
Ey = -X + Y*(1-X*X - Y*Y)*(X*X + Y*Y-4) 

# Depict illustration


fig = plt.figure(figsize=(20,10))
gs = gridspec.GridSpec(nrows=1, ncols=2, width_ratios = [1,1])

# change default range so that new circles will work

# change default range so that new circles will work
ax1 = fig.add_subplot(gs[0,0])
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=4, linewidth=1.5)
ax1.add_patch(circle1)
ax1.add_patch(circle2)
ax1.add_patch(circle3)
ax1.add_patch(circle4)
ax1.set_title("Attracting Set is disc the with R=2 ", fontsize =20)
ax1.set_aspect('equal')
ax1.axis("off")

ax1 = fig.add_subplot(gs[0,1])
ax1.set_xlim((-3, 3))
ax1.set_ylim((-3, 3))
ax1.streamplot(X,Y,Ex,Ey,density=4, linewidth=1.5)
ax1.add_patch(circle11)
ax1.add_patch(circle22)
ax1.add_patch(circle33)
ax1.add_patch(wedge)
ax1.set_title("Attracting Set is the circle R=2", fontsize =20)
ax1.set_aspect('equal')
ax1.axis("off")
# Out:
# (-3.0, 3.0, -3.0, 3.0)

# %%
    
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle2 = plt.Circle((1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle3 = plt.Circle((-1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle11 = plt.Circle((0, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle22 = plt.Circle((1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle33 = plt.Circle((-1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle111 = plt.Circle((0, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle222 = plt.Circle((1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle333 = plt.Circle((-1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle1111 = plt.Circle((0, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle2222 = plt.Circle((1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle3333 = plt.Circle((-1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)

circle11111 = plt.Circle((0, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle22222 = plt.Circle((1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)
circle33333 = plt.Circle((-1/1.414, 0), 0.02, color='r',fill=True,linewidth=3,zorder=10)

wedge = mpatches.Wedge((0, 0), 2.5, 0, 360, width=1,color='tab:orange', zorder=0)
# 1D arrays
x = np.arange(-2,2,0.02)
y = np.arange(-2,2,0.02)

# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y 
Ey = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 


# Depict illustration


fig = plt.figure(figsize=(30,30))
gs = gridspec.GridSpec(nrows=3, ncols=3,  height_ratios = [2,1,1], width_ratios = [1,1,1])


ax1 = fig.add_subplot(gs[0,1])
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))
ax1.streamplot(X,Y,Ex,Ey,density=3, linewidth=1.5)


ax1.add_patch(circle1)
ax1.add_patch(circle2)
ax1.add_patch(circle3)

x = np.arange(0.01,1.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3, zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
x = np.arange(-1.01,-0.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5, label='L=0')


X=0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')


X=-0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=-0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')






z=np.sqrt((2+np.sqrt(6))/4)

x = np.arange(0.01,z,0.0001)

y = np.sqrt(-x**4+x**2 +1/8)
ax1.plot(x,y,'g--',linewidth=3, zorder =5)
ax1.plot(x,-y,'g--',linewidth=3,zorder =5)
ax1.plot(-x,y,'g--',linewidth=3, zorder =5)
ax1.plot(-x,-y,'g--',linewidth=3,zorder =5)


z=np.sqrt((2+np.sqrt(2))/4)
x = np.arange(0.01,z,0.0001)

y = np.sqrt(-x**4+x**2 -1/8)
ax1.plot(x,y,'m--',linewidth=3, zorder =5)
ax1.plot(x,-y,'m--',linewidth=3,zorder =5)
ax1.plot(-x,y,'m--',linewidth=3, zorder =5)
ax1.plot(-x,-y,'m--',linewidth=3,zorder =5)




ax1.set_title("Phase Portrait", fontsize =20)
ax1.set_aspect('equal')


ax1 = fig.add_subplot(gs[1,0])
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))



ax1.add_patch(circle11)
ax1.add_patch(circle22)
ax1.add_patch(circle33)

x = np.arange(0.01,1.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3, zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
x = np.arange(-1.01,-0.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)


X=0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')


X=-0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=-0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

z=np.sqrt((2+np.sqrt(6))/4)

x = np.arange(0.01,z,0.0001)
y = np.sqrt(-x**4+x**2 +1/8)
ax1.plot(x,y,'g--',linewidth=3, zorder =5)
ax1.plot(x,-y,'g--',linewidth=3,zorder =5)
ax1.plot(-x,y,'g--',linewidth=3, zorder =5)
ax1.plot(-x,-y,'g--',linewidth=3,zorder =5)


z=np.sqrt((2+np.sqrt(2))/4)
x = np.arange(0.01,z,0.0001)


f = lambda x,y : (-x**2 +x**4 +y**2)/2

d = np.linspace(-2,2,2000)
x,y = np.meshgrid(d,d)
z = (-0.126<=f(x,y)) & (f(x,y)<=0.125/2).astype(int) 

cmap = matplotlib.colors.ListedColormap(["k","k"])
ax1.contourf(x,y,z, [0.99999, 1.00001], cmap=cmap)
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))
ax1.set_aspect('equal')
ax1.set_title(" L <= 1/16", fontsize =20)
ax1.axis("off")




ax2 = fig.add_subplot(gs[1, 1])
ax2.arrow(-1, 0, 1.6, 0,shape='full',head_width=0.2)
ax2.set_xlim((-1.2, 1.2))
ax2.set_ylim((-1.2, 1.2))
ax1.set_aspect('equal')
ax2.axis("off")

ax1 = fig.add_subplot(gs[1,2])
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))




x = np.arange(0.01,1.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3, zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
x = np.arange(-1.01,-0.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)




f = lambda x,y : (-x**2 +x**4 +y**2)/2

d = np.linspace(-2,2,2000)
x,y = np.meshgrid(d,d)
z = (f(x,y)<=0.001).astype(int) 

cmap = matplotlib.colors.ListedColormap(["tab:orange","tab:orange"])
ax1.contourf(x,y,z, [0.99999, 1.00001], cmap=cmap)
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))
ax1.set_title("L <= 0", fontsize =20)
ax1.set_aspect('equal')
ax1.axis("off")


##########################################################







ax1 = fig.add_subplot(gs[2,0])
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))



ax1.add_patch(circle111)
ax1.add_patch(circle222)
ax1.add_patch(circle333)

x = np.arange(0.01,1.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3, zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
x = np.arange(-1.01,-0.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)


X=0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')


X=-0.5
Y = np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

X=-0.5
Y = -np.sqrt(-X**4+X**2)

dX = Y 
dY = X - 2*X**3 + Y*(X**2 -X**4 -Y**2) 

ax1.arrow(X, Y, dX/30, dY/30, head_width=0.05, head_length=0.1, fc='tab:orange', ec='tab:orange')

z=np.sqrt((2+np.sqrt(6))/4)

x = np.arange(0.01,z,0.0001)

y = np.sqrt(-x**4+x**2 +1/8)
ax1.plot(x,y,'g--',linewidth=3, zorder =5)
ax1.plot(x,-y,'g--',linewidth=3,zorder =5)
ax1.plot(-x,y,'g--',linewidth=3, zorder =5)
ax1.plot(-x,-y,'g--',linewidth=3,zorder =5)


z=np.sqrt((2+np.sqrt(2))/4)
x = np.arange(0.01,z,0.0001)


f = lambda x,y : (-x**2 +x**4 +y**2)/2

d = np.linspace(-2,2,2000)
x,y = np.meshgrid(d,d)
z = (-0.126/2<=f(x,y)) & (f(x,y)<=0.125/2).astype(int) 

cmap = matplotlib.colors.ListedColormap(["k","k"])
ax1.contourf(x,y,z, [0.99999, 1.00001], cmap=cmap)
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))
ax1.set_title("-1/16<= L <= 1/16", fontsize =20)
ax1.set_aspect('equal')
ax1.axis("off")


ax2 = fig.add_subplot(gs[2, 1])
ax2.arrow(-1, 0, 1.6, 0,shape='full',head_width=0.2)
ax2.set_xlim((-1.2, 1.2))
ax2.set_ylim((-1.2, 1.2))
ax1.set_aspect('equal')
ax2.axis("off")


ax1 = fig.add_subplot(gs[2,2])
ax1.set_xlim((-1.2, 1.2))
ax1.set_ylim((-1.2, 1.2))



x = np.arange(0.01,1.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3, zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
x = np.arange(-1.01,-0.01,0.01)
y = np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)
y = -np.sqrt(-x**4+x**2)
ax1.plot(x,y,color='tab:orange',linewidth=3,zorder =5)

ax1.set_title("L=0", fontsize =20)
ax1.set_aspect('equal')
ax1.axis("off")
plt.show()
# Out:
# <ipython-input-268-333385dc2778>:59: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:61: RuntimeWarning: invalid value encountered in sqrt
#   y = -np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:117: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(-x**4+x**2 -1/8)
# <ipython-input-268-333385dc2778>:146: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:148: RuntimeWarning: invalid value encountered in sqrt
#   y = -np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:236: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:238: RuntimeWarning: invalid value encountered in sqrt
#   y = -np.sqrt(-x**4+x**2)
# <ipython-input-268-333385dc2778>:283: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(-x**4+x**2)
# ...

# %%
    
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

f = lambda x,y : (-x**2 +x**4 +y**2)/2

d = np.linspace(-2,2,2000)
x,y = np.meshgrid(d,d)
z = (-0.126<=f(x,y)) & (f(x,y)<=0.001).astype(int) 

cmap = matplotlib.colors.ListedColormap(["k","k"])
plt.contourf(x,y,z, [0.99999, 1.00001], cmap=cmap)

plt.show()

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

circle1 = plt.Circle((0, 0), 2, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), 1, color='tab:orange',fill=True,linewidth=3)
circle3 = plt.Circle((0, 0), 0.3, color='y',fill=True,linewidth=3)
circle11 = plt.Circle((0, 0), 2, color='r',fill=True,linewidth=3)
circle22 = plt.Circle((0, 0), 1, color='tab:orange',fill=True,linewidth=3)
circle33 = plt.Circle((0, 0), 0.3, color='y',fill=True,linewidth=3)
# 1D arrays
x = np.arange(-4,4,0.02)
y = np.arange(-4,4,0.02)

# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
Ex = Y - X*np.sqrt(X*X + Y*Y )
Ey = -X - Y*np.sqrt( X*X + Y*Y )

# Depict illustration

fig=plt.figure(figsize=(20, 20))
gs = gridspec.GridSpec(nrows=1, ncols=2,  width_ratios = [1,1])
ax = fig.add_subplot(gs[0,0])
p = np.linspace(-2,2,100)
q = 0*p
ax.plot(p, q, '-k',linewidth=2,zorder=0)
ax.plot(q, p, '-k',linewidth=2,zorder=0)
x=np.linspace(0,1,100)
y=np.sqrt(1-x**2)
ax.plot(x, y, '-b',linewidth=2,zorder=0)
x=np.linspace(0,1.1,101)
y=np.sqrt(1.21001-x**2)
ax.plot(x, y, '-r',linewidth=2,zorder=0)
ax.set_xlim((-1.2, 1.2))
ax.set_ylim((-1.2, 1.2))


x=1
y = 0

dX = y
dY = -x
ax.arrow(x, y, dX/100, dY/100, head_width=0.05, head_length=0.1, fc='b', ec='b')

x=1.1
y = 0

dX = y
dY = -x
ax.arrow(x, y, dX/100, dY/100, head_width=0.05, head_length=0.1, fc='r', ec='r')


ax.set_title("flows with same angular velocity", fontsize =20)
ax.set_aspect('equal')
ax.axis("off")



ax = fig.add_subplot(gs[0,1])
p = np.linspace(-2,2,100)
q = 0*p
ax.plot(p, q, '-k',linewidth=2,zorder=0)
ax.plot(q, p, '-k',linewidth=2,zorder=0)
x=np.linspace(0,1,100)
y=np.sqrt(1-x**2)
ax.plot(x, y, '-b',linewidth=2,zorder=0)
x=np.linspace(0,1.1,101)
y=np.sqrt(1.21001-x**2)

ax.plot(x, y, '-r',linewidth=2,zorder=0)
x=np.linspace(0.8,1.1,101)
y=-np.sqrt(1.21001-x**2)
ax.plot(x, y, '-r',linewidth=2,zorder=0)
ax.set_xlim((-1.2, 1.2))
ax.set_ylim((-1.2, 1.2))

x=1
y = 0

dX = y
dY = -x

ax.arrow(x, y, dX/100, dY/100, head_width=0.05, head_length=0.1, fc='b', ec='b')

x=0.8
y=-np.sqrt(1.21001-x**2)

dX = y
dY = -x
ax.arrow(x, y, dX/100, dY/100, head_width=0.05, head_length=0.1, fc='r', ec='r')

ax.set_title("flows with different angular velocity", fontsize =20)
ax.set_aspect('equal')

ax.axis("off")
# Out:
# (-1.2, 1.2, -1.2, 1.2)
