# %% [markdown]
# ### The Saddle-Node Bifurcation

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle2 = plt.Circle((1, 0), r, color='r',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle4 = plt.Circle((1, 0), r, color='r',fill=True,linewidth=3)
wedge1 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge2 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)
wedge3 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge4 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)




# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=2, ncols=3,height_ratios = [1,2], width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p



r=-1
ax1 = fig.add_subplot(gs[0, 0])
X = [-2,-1.5,-0.5,0,0.5,0.8,1.2,1.7]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)

U =[0.3,0.3,-0.3,-0.3,-0.3,-0.3,0.3,0.3]
ax1.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax1.add_patch(circle1)
ax1.add_patch(circle2)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax1.set_xlim((-2, 2))
ax1.set_ylim((-3, 1))
ax1.set_title('Phase Portrait r=-1',fontsize=20)
ax1.axis('off')

ax2 = fig.add_subplot(gs[1, 0])
x = np.linspace(-2,2,100)
y = r+x**2 

ax2.plot(x, y, '-k',linewidth=1,zorder=0)
ax2.set_title('Dynamics Plot r=-1',fontsize=20)
ax2.add_patch(circle3)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-1, 3))



plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 


r=0

ax3 = fig.add_subplot(gs[0, 1])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
U =[0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3]
ax3.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax3.add_patch(wedge3)
ax3.add_patch(wedge4)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax3.set_xlim((-2, 2))
ax3.set_ylim((-3, 1))
ax3.set_title('Phase Portrait r=0',fontsize=20)
ax3.axis('off')


ax4 = fig.add_subplot(gs[1, 1])
x = np.linspace(-2,2,100)
y = r+x**2 
ax4.plot(x, y, '-k',linewidth=1,zorder=0)
ax4.set_title('r=0')
ax4.set_xlim((-2, 2))
ax4.set_ylim((-1, 3))
ax4.add_patch(wedge1)
ax4.add_patch(wedge2)
ax4.plot(p, q, '-k',linewidth=2,zorder=0)
ax4.set_title('Dynamics Plot r=0',fontsize=20)
ax4.set_aspect('equal')

r=1
ax5 = fig.add_subplot(gs[0, 2])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.3]
ax5.quiver(X, Y, U, V, color='k', units='xy', scale=1)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax5.set_xlim((-2, 2))
ax5.set_ylim((-3, 1))
ax5.set_title('Phase Portrait r=1',fontsize=20)
ax5.axis('off')

ax6 = fig.add_subplot(gs[1, 2])
x = np.linspace(-2,2,100)
y = r+x**2 
ax6.plot(x, y, '-k',linewidth=1,zorder=0)
ax6.set_title('Dynamics Plot r=1',fontsize=20)
ax6.set_xlim((-2, 2))
ax6.set_ylim((-1, 3))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax6.set_aspect('equal')


# Show plot with gird

plt.show()

# %% [markdown]
# ### The Transcritical Bifurcation

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle4 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle5 = plt.Circle((0, 0), r, color='#7f6000',fill=True,linewidth=3)
circle6 = plt.Circle((0, 0), r, color='#7f6000',fill=True,linewidth=3)
circle7 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle8 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle9 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3,zorder=10)
circle10 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
wedge1 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge2 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)
wedge3 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge4 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)




# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=2, ncols=3,height_ratios = [1,2], width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p



r=-1
ax1 = fig.add_subplot(gs[0, 0])
X = [-2,-1.5,-0.5,0,0.5,0.8,1.2,1.7]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)

U =[-0.3,-0.3,0.2,-0.2,-0.3,-0.3,-0.3,-0.3]
ax1.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax1.add_patch(circle1)
ax1.add_patch(circle2)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax1.set_xlim((-2, 2))
ax1.set_ylim((-3, 1))
ax1.set_title('Phase Portrait r=-1',fontsize=20)
ax1.axis('off')

ax2 = fig.add_subplot(gs[1, 0])
x = np.linspace(-2,2,100)
y = r*x-x**2 

ax2.plot(x, y, '-k',linewidth=1,zorder=0)
ax2.set_title('Dynamics Plot r=-1',fontsize=20)
ax2.add_patch(circle3)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-1, 3))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 


r=0

ax3 = fig.add_subplot(gs[0, 1])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
U =[-0.3,-0.3,-0.3,-0.3,-0.3,-0.3,-0.3,-0.3,-0.3]
ax3.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax3.add_patch(circle5)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax3.set_xlim((-2, 2))
ax3.set_ylim((-3, 1))
ax3.set_title('Phase Portrait r=0',fontsize=20)
ax3.axis('off')


ax4 = fig.add_subplot(gs[1, 1])
x = np.linspace(-2,2,100)
y = r*x-x**2
ax4.plot(x, y, '-k',linewidth=1,zorder=0)
ax4.set_title('r=0')
ax4.set_xlim((-2, 2))
ax4.set_ylim((-1, 3))
ax4.add_patch(circle6)
ax4.plot(p, q, '-k',linewidth=2,zorder=0)
ax4.set_title('Dynamics Plot r=0',fontsize=20)
ax4.set_aspect('equal')

r=1
ax5 = fig.add_subplot(gs[0, 2])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[-0.3,-0.3,-0.3,-0.3,0.3,0.2,-0.4,-0.5,-0.6]
ax5.quiver(X, Y, U, V, color='k', units='xy', scale=1)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax5.set_xlim((-2, 2))
ax5.set_ylim((-3, 1))
ax5.add_patch(circle7)
ax5.add_patch(circle8)
ax5.set_title('Phase Portrait r=1',fontsize=20)
ax5.axis('off')

ax6 = fig.add_subplot(gs[1, 2])
x = np.linspace(-2,2,100)
y = r*x-x**2 
ax6.plot(x, y, '-k',linewidth=1,zorder=0)
ax6.set_title('Dynamics Plot r=1',fontsize=20)
ax6.set_xlim((-2, 2))
ax6.set_ylim((-1, 3))
ax6.add_patch(circle9)
ax6.add_patch(circle10)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax6.set_aspect('equal')


# Show plot with gird

plt.show()

# %% [markdown]
# ### Pitchfork Bifurcation (Super-Critical)

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle4 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle5 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle6 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)

circle7 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle8 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle9 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)

circle10 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3,zorder=10)
circle11 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle12 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
wedge1 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge2 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)
wedge3 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge4 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)




# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=2, ncols=3,height_ratios = [1,2], width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p



r=-1
ax1 = fig.add_subplot(gs[0, 0])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[0.3,0.3,0.3,0.3,-0.3,-0.3,-0.3,-0.3,-0.3]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
ax1.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax1.add_patch(circle2)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax1.set_xlim((-2, 2))
ax1.set_ylim((-3, 1))
ax1.set_title('Phase Portrait r=-1',fontsize=20)
ax1.axis('off')

ax2 = fig.add_subplot(gs[1, 0])
x = np.linspace(-2,2,100)
y = r*x-x**3 

ax2.plot(x, y, '-k',linewidth=1,zorder=0)
ax2.set_title('Dynamics Plot r=-1',fontsize=20)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-3, 3))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 


r=0

ax3 = fig.add_subplot(gs[0, 1])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[0.3,0.3,0.3,0.3,-0.3,-0.3,-0.3,-0.3,-0.3]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
U =[0.3,0.3,0.3,0.3,-0.3,-0.3,-0.3,-0.3,-0.3]
ax3.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax3.add_patch(circle5)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax3.set_xlim((-2, 2))
ax3.set_ylim((-3, 1))
ax3.set_title('Phase Portrait r=0',fontsize=20)
ax3.axis('off')


ax4 = fig.add_subplot(gs[1, 1])
x = np.linspace(-2,2,100)
y = r*x-x**3
ax4.plot(x, y, '-k',linewidth=1,zorder=0)
ax4.set_title('r=0')
ax4.set_xlim((-2, 2))
ax4.set_ylim((-3, 3))
ax4.add_patch(circle6)
ax4.plot(p, q, '-k',linewidth=2,zorder=0)
ax4.set_title('Dynamics Plot r=0',fontsize=20)
ax4.set_aspect('equal')

r=1
ax5 = fig.add_subplot(gs[0, 2])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[0.3,0.3,0,-0.3,0.3,0.2,-0.4,-0.5,-0.6]
ax5.quiver(X, Y, U, V, color='k', units='xy', scale=1)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax5.set_xlim((-2, 2))
ax5.set_ylim((-3, 1))
ax5.add_patch(circle7)
ax5.add_patch(circle8)
ax5.add_patch(circle9)
ax5.set_title('Phase Portrait r=1',fontsize=20)
ax5.axis('off')

ax6 = fig.add_subplot(gs[1, 2])
x = np.linspace(-2,2,100)
y = r*x-x**3 
ax6.plot(x, y, '-k',linewidth=1,zorder=0)
ax6.set_title('Dynamics Plot r=1',fontsize=20)
ax6.set_xlim((-2, 2))
ax6.set_ylim((-3, 3))
ax6.add_patch(circle10)
ax6.add_patch(circle11)
ax6.add_patch(circle12)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax6.set_aspect('equal')


# Show plot with gird

plt.show()

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle4 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle5 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle6 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)

circle7 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle8 = plt.Circle((1, 0), r, color='r',fill=True,linewidth=3)
circle9 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)

circle10 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3,zorder=10)
circle11 = plt.Circle((1, 0), r, color='r',fill=True,linewidth=3)
circle12 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
wedge1 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge2 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)
wedge3 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge4 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)




# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=2, ncols=3,height_ratios = [1,2], width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p



r=-1
ax1 = fig.add_subplot(gs[0, 0])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[-0.3,-0.3,-0.4,0.3,-0.4,-0.2,0.3,0.3,0.3]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
ax1.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax1.add_patch(circle7)
ax1.add_patch(circle8)
ax1.add_patch(circle9)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax1.set_xlim((-2, 2))
ax1.set_ylim((-3, 1))
ax1.set_title('Phase Portrait r=-1',fontsize=20)
ax1.axis('off')

ax2 = fig.add_subplot(gs[1, 0])
x = np.linspace(-2,2,100)
y = r*x+x**3 

ax2.plot(x, y, '-k',linewidth=1,zorder=0)
ax2.set_title('Dynamics Plot r=-1',fontsize=20)
ax2.add_patch(circle10)
ax2.add_patch(circle11)
ax2.add_patch(circle12)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-3, 3))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 


r=0

ax3 = fig.add_subplot(gs[0, 1])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[0.3,0.3,0.3,0.3,-0.3,-0.3,-0.3,-0.3,-0.3]
Y=[]
V=[]
for x in X:
    Y.append(0.0)
    V.append(0.0)
U =[-0.3,-0.3,-0.3,-0.3,0.3,0.3,0.3,0.3,0.3]
ax3.quiver(X, Y, U, V, color='k', units='xy', scale=1)
ax3.add_patch(circle5)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax3.set_xlim((-2, 2))
ax3.set_ylim((-3, 1))
ax3.set_title('Phase Portrait r=0',fontsize=20)
ax3.axis('off')


ax4 = fig.add_subplot(gs[1, 1])
x = np.linspace(-2,2,100)
y = r*x+x**3
ax4.plot(x, y, '-k',linewidth=1,zorder=0)
ax4.set_title('r=0')
ax4.set_xlim((-2, 2))
ax4.set_ylim((-3, 3))
ax4.add_patch(circle6)
ax4.plot(p, q, '-k',linewidth=2,zorder=0)
ax4.set_title('Dynamics Plot r=0',fontsize=20)
ax4.set_aspect('equal')

r=1
ax5 = fig.add_subplot(gs[0, 2])
X = [-2,-1.5,-1,-0.5,0.2,0.7,1.2,1.7,2.2]
U =[-0.3,-0.3,0,-0.3,-0.3,0.2,0.4,0.5,0.6]
ax5.add_patch(circle2)

ax5.quiver(X, Y, U, V, color='k', units='xy', scale=1)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax5.set_xlim((-2, 2))
ax5.set_ylim((-3, 1))

ax5.set_title('Phase Portrait r=1',fontsize=20)
ax5.axis('off')

ax6 = fig.add_subplot(gs[1, 2])
x = np.linspace(-2,2,100)
y = r*x+x**3 
ax6.plot(x, y, '-k',linewidth=1,zorder=0)
ax6.set_title('Dynamics Plot r=1',fontsize=20)
ax6.set_xlim((-2, 2))
ax6.set_ylim((-3, 3))
ax6.add_patch(circle4)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
ax6.set_aspect('equal')


# Show plot with gird

plt.show()

# %% [markdown]
# ### Bifurcation Diagram

# %%
import numpy as np
import matplotlib.pyplot as plt

p = np.linspace(-5,5,100)
q = 0*p
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
ax.plot(p, q, '-k',linewidth=1,zorder=0)
ax.plot(q, p, '-k',linewidth=1,zorder=0)

r = np.linspace(-6,0,100)
x1 = np.sqrt(-r)
x2 = -np.sqrt(-r)
ax.plot(r, x1, 'b--',linewidth=2,zorder=0)
ax.plot(r, x2, '-b',linewidth=2,zorder=0)

ax.text(5, 0.2, 'r', fontsize=16)
ax.text(0.1, 5, 'x', fontsize=16)
ax.text(-5, 3, 'unstable', fontsize=16)
ax.text(-5, -3.2, 'stable', fontsize=16)
ax.set_title('Saddle-Node Bifurcation',fontsize=20)
ax.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

p = np.linspace(-5,5,100)
q = 0*p
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
ax.plot(p, q, '-k',linewidth=1,zorder=0)
ax.plot(q, p, '-k',linewidth=1,zorder=0)

r = np.linspace(-5,0,100)
x1 = r
x2 = 0*r
ax.plot(r, x1, 'b--',linewidth=3,zorder=0)
ax.plot(r, x2, '-b',linewidth=3,zorder=0)

r = np.linspace(0,5,100)
x1 = r
x2 = 0*r
ax.plot(r, x1, 'b',linewidth=3,zorder=10)
ax.plot(r, x2, 'b--',linewidth=3,zorder=10)

ax.text(5, 0.2, 'r', fontsize=16)
ax.text(0.1, 5, 'x', fontsize=16)
ax.text(-5, 0.2, 'stable', fontsize=16)
ax.text(-5, -3.2, 'unstable', fontsize=16)
ax.set_title('Transcritical Bifurcation',fontsize=20)
ax.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

p = np.linspace(-5,5,100)
q = 0*p
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
ax.plot(p, q, '-k',linewidth=1,zorder=0)
ax.plot(q, p, '-k',linewidth=1,zorder=0)

r = np.linspace(-5,0,100)
x1 = r
x2 = 0*r
ax.plot(r, x2, '-b',linewidth=3,zorder=0)

r = np.linspace(0,5,100)
x1 = np.sqrt(r)
x2 = 0*r
x3 = -np.sqrt(r)
ax.plot(r, x1, 'b',linewidth=3,zorder=10)
ax.plot(r, x2, 'b--',linewidth=3,zorder=10)
ax.plot(r, x3, 'b',linewidth=3,zorder=10)
ax.text(5, 0.2, 'r', fontsize=16)
ax.text(0.1, 5, 'x', fontsize=16)
ax.text(-5, 0.2, 'stable', fontsize=16)
ax.text(4, 2.5, 'stable', fontsize=16)
ax.text(4, -2.5, 'stable', fontsize=16)
ax.text(4, -.5, 'unstable', fontsize=16)
ax.set_title('Pitchfork Bifurcation I: Super-Critical Case',fontsize=20)
ax.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

p = np.linspace(-5,5,100)
q = 0*p
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
ax.plot(p, q, '-k',linewidth=1,zorder=0)
ax.plot(q, p, '-k',linewidth=1,zorder=0)

r = np.linspace(-5,0,100)
x1 = np.sqrt(-r)
x2 = 0*r
x3 = -np.sqrt(-r)
ax.plot(r, x1, 'b--',linewidth=3,zorder=0)
ax.plot(r, x2, 'b-',linewidth=3,zorder=0)
ax.plot(r, x3, 'b--',linewidth=3,zorder=0)

r = np.linspace(0,5,100)

x2 = 0*r

ax.plot(r, x2, 'b--',linewidth=3,zorder=10)

ax.text(5, 0.2, 'r', fontsize=16)
ax.text(0.1, 5, 'x', fontsize=16)
ax.text(-5, 0.2, 'stable', fontsize=16)
ax.text(-5, 2.5, 'unstable', fontsize=16)
ax.text(-5, -2.5, 'unstable', fontsize=16)
ax.text(4, -.5, 'unstable', fontsize=16)
ax.set_title('Pitchfork Bifurcation II: Sub-Critical Case',fontsize=20)
ax.axis('off')
plt.show()

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(20,20))
gs = gridspec.GridSpec(nrows=1, ncols=3, width_ratios = [1,1,1])



# 1D arrays
x = np.arange(-1.5,0.5,0.01)
y = np.arange(-1,1,0.01)


# Meshgrid
X,Y = np.meshgrid(x,y)

# Assign vector directions
r=-1
ax1 = fig.add_subplot(gs[0, 0])
Ex = r*X-X**2
Ey = -Y
# Depict illustration
ax1.streamplot(X,Y,Ex,Ey,color='b', density=1.5, linewidth=1)
ax1.plot(r,0,'-or')
ax1.plot(0,0,'-og')
ax1.set_aspect('equal')
x1 = x
x2 = 0*x
ax1.plot(x, x2, 'k-',linewidth=2,zorder=0)
x1 = y
x2=0*y-1
x3=0*y
ax1.plot(x2, y, 'k-',linewidth=2,zorder=0)
ax1.plot(x3, y, 'k-',linewidth=2,zorder=0)
circle1 = plt.Circle((-1, 0), 0.05, color='r',fill=True,linewidth=3,zorder=10)
circle2 = plt.Circle((0, 0), 0.05, color='g',fill=True,linewidth=3,zorder=10)
ax1.add_patch(circle1)
ax1.add_patch(circle2)
# Show plot with gird
ax1.set_xlim((-1.5, 0.5))
ax1.set_ylim((-1, 1))
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
ax1.set_title("Phase Portrait r=-1",fontsize=20)
r=0
# 1D arrays
x = np.arange(-1,1,0.01)
y = np.arange(-1,1,0.01)


# Meshgrid
X,Y = np.meshgrid(x,y)
ax1 = fig.add_subplot(gs[0, 1])
Ex = r*X-X**2
Ey = -Y
# Depict illustration
ax1.streamplot(X,Y,Ex,Ey,color='b', density=1.5, linewidth=1)
ax1.set_aspect('equal')
x1 = x
x2 = 0*x
ax1.plot(x, x2, 'k-',linewidth=2,zorder=0)
x1 = y
x3=0*y
ax1.plot(x3, y, 'k-',linewidth=2,zorder=0)
circle3 = plt.Circle((0, 0), 0.05, color='y',fill=True,linewidth=3,zorder=10)
ax1.add_patch(circle3)

# Show plot with gird
ax1.set_xlim((-1, 1))
ax1.set_ylim((-1, 1))
ax1.set_title("Phase Portrait r=0",fontsize=20)
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)

r=1
# 1D arrays
x = np.arange(-0.5,1.5,0.01)
y = np.arange(-1,1,0.01)


# Meshgrid
X,Y = np.meshgrid(x,y)
ax1 = fig.add_subplot(gs[0, 2])
Ex = r*X-X**2
Ey = -Y
# Depict illustration
ax1.streamplot(X,Y,Ex,Ey,color='b', density=1.5, linewidth=1)
ax1.set_aspect('equal')
x1 = x
x2 = 0*x
ax1.plot(x, x2, 'k-',linewidth=2,zorder=0)
x1 = y
x2= 0*y+1
x3=0*y
ax1.plot(x2, y, 'k-',linewidth=2,zorder=0)
ax1.plot(x3, y, 'k-',linewidth=2,zorder=0)
circle4 = plt.Circle((0, 0), 0.05, color='r',fill=True,linewidth=3,zorder=10)
circle5 = plt.Circle((1, 0), 0.05, color='g',fill=True,linewidth=3,zorder=10)
ax1.add_patch(circle4)
ax1.add_patch(circle5)
# Show plot with gird
ax1.set_xlim((-0.5, 1.5))
ax1.set_ylim((-1, 1))
ax1.set_title("Phase Portrait r=1",fontsize=20)
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
#plt.grid()

plt.show()

# %% [markdown]
# ### Hopf Bifurcation

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(20,20))
gs = gridspec.GridSpec(nrows=1, ncols=3, width_ratios = [1,1,1])
# 1D arrays
X = np.arange(-2,2,0.01)
Y = np.arange(-2,2,0.01)


# Meshgrid
x,y = np.meshgrid(X,Y)

ax0 = fig.add_subplot(gs[0, 0])
a=-1

u = (a-(x*x +y*y))*x-(1+(x*x +y*y))*y
v = (a-(x*x +y*y))*y+(1+(x*x +y*y))*x
ax0.streamplot(x, y, u, v,density =2, linewidth=None)
ax0.set_title('Phase Portrait for a=-1',fontsize=16)
circle1 = plt.Circle((0, 0), 0.05, color='g',fill=True,linewidth=3,zorder=5)
ax0.add_patch(circle1)
ax0.set_xlim((-2, 2))
ax0.set_ylim((-2, 2))
ax0.set_aspect('equal')

ax1 = fig.add_subplot(gs[0, 1])

a=0
u1 = (a-(x*x +y*y))*x-(1+(x*x +y*y))*y
v1 = (a-(x*x +y*y))*y+(1+(x*x +y*y))*x
ax1.streamplot(x, y, u1, v1,density =2, linewidth=None)
ax1.set_title('Phase Portrait for a=0',fontsize=16)
circle2 = plt.Circle((0, 0), 0.05, color='g',fill=True,linewidth=3,zorder=5)
ax1.add_patch(circle2)
ax1.set_xlim((-2, 2))
ax1.set_ylim((-2, 2))
ax1.set_aspect('equal')

ax2 = fig.add_subplot(gs[0, 2])
a=1
u1 = (a-(x*x +y*y))*x-(1+(x*x +y*y))*y
v1 = (a-(x*x +y*y))*y+(1+(x*x +y*y))*x

ax2.streamplot(x, y, u1, v1,density =2, linewidth=None)
ax2.set_title('Phase Portrait for a=1',fontsize=16)
circle3 = plt.Circle((0, 0), 0.05, color='r',fill=True,linewidth=3,zorder=5)
circle4 = plt.Circle((0, 0), 1, color='g',fill=False,linewidth=3,zorder=5)
ax2.plot(0,0,'-or')
ax2.add_patch(circle3)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
ax2.set_aspect('equal')

plt.show()

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle2 = plt.Circle((-0.5, 0), r, color='g',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='g',fill=True,linewidth=3)
circle4 = plt.Circle((0.5, 0), r, color='r',fill=True,linewidth=3)





# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=1, ncols=3, width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p




ax2 = fig.add_subplot(gs[0, 0])

ax2.set_title('Eigenvalues for r<0',fontsize=20)
ax2.add_patch(circle1)
ax2.add_patch(circle2)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 
ax2.text(2,0.1,"Re", fontsize=16)
ax2.text(0.1,1.8,"Im", fontsize=16)
ax2.text(-1.1,-0.4,"-1", fontsize=16)
ax2.text(-0.55,-0.4,"r", fontsize=16)
ax2.axis("off")

ax2 = fig.add_subplot(gs[0, 1])
ax2.arrow(-1, 0, 2, 0,shape='full',head_width=0.2)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
ax2.axis("off")

ax2 = fig.add_subplot(gs[0, 2])

ax2.set_title('Eigenvalues for r>0',fontsize=20)
ax2.add_patch(circle3)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 
ax2.text(2,0.1,"Re", fontsize=16)
ax2.text(0.1,1.8,"Im", fontsize=16)
ax2.text(-1.1,-0.4,"-1", fontsize=16)
ax2.text(0.45,-0.4,"r", fontsize=16)
ax2.axis("off")

# Show plot with gird

plt.show()

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 1), r, color='g',fill=True,linewidth=3)
circle2 = plt.Circle((-1, -1), r, color='g',fill=True,linewidth=3)
circle3 = plt.Circle((1, 1), r, color='r',fill=True,linewidth=3)
circle4 = plt.Circle((1, -1), r, color='r',fill=True,linewidth=3)





# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=1, ncols=3, width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p




ax2 = fig.add_subplot(gs[0, 0])

ax2.set_title('Eigenvalues for a<0',fontsize=20)
ax2.add_patch(circle1)
ax2.add_patch(circle2)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 
ax2.text(2,0.1,"Re", fontsize=16)
ax2.text(0.1,1.8,"Im", fontsize=16)
ax2.text(-1.2,-1.3,"a-ci", fontsize=16)
ax2.text(-1.2,1.2,"a+ci", fontsize=16)
ax2.axis("off")

ax2 = fig.add_subplot(gs[0, 1])
ax2.arrow(-1, 0, 2, 0,shape='full',head_width=0.2)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
ax2.axis("off")

ax2 = fig.add_subplot(gs[0, 2])

ax2.set_title('Eigenvalues for a>0',fontsize=20)
ax2.add_patch(circle3)
ax2.add_patch(circle4)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 
ax2.text(2,0.1,"Re", fontsize=16)
ax2.text(0.1,1.8,"Im", fontsize=16)
ax2.text(0.8,-1.3,"a-ci", fontsize=16)
ax2.text(0.8,1.2,"a+ci", fontsize=16)
ax2.axis("off")

# Show plot with gird

plt.show()

# %%
#The saddle-node bifurcation
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle3 = plt.Circle((-1, 0), r, color='r',fill=True,linewidth=3)
circle4 = plt.Circle((0, 0), r, color='g',fill=True,linewidth=3)
circle5 = plt.Circle((0, 0), r, color='#7f6000',fill=True,linewidth=3)
circle6 = plt.Circle((0, 0), r, color='#7f6000',fill=True,linewidth=3)
circle7 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3)
circle8 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
circle9 = plt.Circle((0, 0), r, color='r',fill=True,linewidth=3,zorder=10)
circle10 = plt.Circle((1, 0), r, color='g',fill=True,linewidth=3)
wedge1 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge2 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)
wedge3 = mpatches.Wedge((-0.01,0), r, 90, 270,color='g', fill=True, linewidth=3)
wedge4 = mpatches.Wedge((0.02,0), r, 270, 450,color='r', fill=True, linewidth=3)




# Depict illustration
fig = plt.figure(figsize=(15,10))
gs = gridspec.GridSpec(nrows=1, ncols=3, width_ratios = [1,1,1])


 
# Show plot with grid
p = np.linspace(-2,2,100)
x = np.linspace(-2,2,100)
q = 0*p



r=1

ax2 = fig.add_subplot(gs[0, 0])
x = np.linspace(-1,2,100)
y = r*x-2*x/(x+1)
circle1 = plt.Circle((2/r-1, 0), 0.1, color='r',fill=True,linewidth=3)
circle2 = plt.Circle((0, 0), 0.1, color='g',fill=True,linewidth=3)

ax2.plot(x, y, '-k',linewidth=1,zorder=0)
ax2.set_title('Dynamics Plot r=1',fontsize=20)
ax2.add_patch(circle1)
ax2.add_patch(circle2)
ax2.set_xlim((-2, 2))
ax2.set_ylim((-2, 2))
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax2.set_aspect('equal') 


r=2




ax4 = fig.add_subplot(gs[0, 1])
x = np.linspace(-1,2,100)
y = r*x-2*x/(x+1)
ax4.plot(x, y, '-k',linewidth=1,zorder=0)
ax4.set_title('r=0')
ax4.set_xlim((-2, 2))
ax4.set_ylim((-2, 2))
ax4.add_patch(circle6)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax4.set_title('Dynamics Plot r=2',fontsize=20)
ax4.set_aspect('equal')

r=4


ax6 = fig.add_subplot(gs[0, 2])
x = np.linspace(-1,2,100)
y = r*x-2*x/(x+1)
ax6.plot(x, y, '-k',linewidth=1,zorder=0)
ax6.set_title('Dynamics Plot r=4',fontsize=20)
ax6.set_xlim((-2, 2))
ax6.set_ylim((-2, 2))
circle5 = plt.Circle((2/r-1, 0), 0.1, color='g',fill=True,linewidth=3)
circle6 = plt.Circle((0, 0), 0.1, color='r',fill=True,linewidth=3)
ax6.add_patch(circle5)
ax6.add_patch(circle6)
plt.plot(p, q, '-k',linewidth=2,zorder=0)
plt.plot(q, p, '-k',linewidth=2,zorder=0)
ax6.set_aspect('equal')


# Show plot with gird

plt.show()
# Out:
# <ipython-input-39-a45607938b6c>:43: RuntimeWarning: divide by zero encountered in true_divide
#   y = r*x-2*x/(x+1)
# <ipython-input-39-a45607938b6c>:65: RuntimeWarning: divide by zero encountered in true_divide
#   y = r*x-2*x/(x+1)
# <ipython-input-39-a45607938b6c>:81: RuntimeWarning: divide by zero encountered in true_divide
#   y = r*x-2*x/(x+1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
r=0.1
circle1 = plt.Circle((2, 0), r, color='r',fill=True,linewidth=3,zorder=10)

p = np.linspace(-5,5,100)
q = 0*p
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot()
ax.plot(p, q, '-k',linewidth=1,zorder=0)
ax.plot(q, p, '-k',linewidth=1,zorder=0)

r = np.linspace(0.3,2,100)
x1 = 2/r-1
x2 = 0*r
ax.plot(r, x1, 'b--',linewidth=3,zorder=0)
ax.plot(r, x2, '-b',linewidth=3,zorder=0)

r = np.linspace(2,6,100)
x1 = 2/r-1
x2 = 0*r
ax.plot(r, x1, 'b',linewidth=3,zorder=5)
ax.plot(r, x2, 'b--',linewidth=3,zorder=5)

ax.text(5, 0.2, 'r', fontsize=16)
ax.text(0.1, 5, 'x', fontsize=16)
ax.text(6, -1.2, 'stable', fontsize=16)
ax.text(6, 0.2, 'unstable', fontsize=16)
ax.set_title('Transcritical Bifurcation',fontsize=20)
ax.add_patch(circle1)

ax.axis('off')
plt.show()
